# %%
# run
# !ip -br -4 addr | grep -v 127.0.0.1
# and use the adress, e.g., 172.17.0.2 to connect workers to server

# %%
# !celery -A experiments_run -b redis://172.17.0.2:6379/0 --result-backend redis://172.17.0.2:6379/0 worker --loglevel=info --concurrency=48
# Out:
# 2025-07-09 13:07:56,575 [INFO] tensorflow is not installed, and sparse Hamiltonian generation utilities are disabled
# 2025-07-09 13:07:56,964 [WARNING] Please first ``pip install -U qiskit`` to enable related functionality in translation module
# 2025-07-09 13:07:56,964 [WARNING] Please first ``pip install -U cirq`` to enable related functionality in translation module
# /usr/local/lib/python3.10/dist-packages/celery/platforms.py:841: SecurityWarning: You're running the worker with superuser privileges: this is
# absolutely not recommended!
#
# Please specify a different user using the --uid option.
#
# User information: uid=0 euid=0 gid=0 egid=0
#
#   warnings.warn(SecurityWarning(ROOT_DISCOURAGED.format(
#
#  -------------- celery@91de2d820aa3 v5.5.0 (immunity)
# --- ***** -----
# -- ******* ---- Linux-4.18.0-372.13.1.0.1.el8_6.x86_64-x86_64-with-glibc2.35 2025-07-09 13:07:59
# - *** --- * ---
# - ** ---------- [config]
# - ** ---------- .> app:         experiments_run:0x7f3062cbfd60
# - ** ---------- .> transport:   redis://172.17.0.2:6379/0
# - ** ---------- .> results:     redis://172.17.0.2:6379/0
# - *** --- * --- .> concurrency: 48 (prefork)
# -- ******* ---- .> task events: OFF (enable -E to monitor tasks in this worker)
# --- ***** -----
#  -------------- [queues]
#                 .> celery           exchange=celery(direct) key=celery
#
#
# [tasks]
#   . experiments_run.run_experiment_task
#
# [2025-07-09 13:08:18,186: INFO/MainProcess] Connected to redis://172.17.0.2:6379/0
# [2025-07-09 13:08:18,189: INFO/MainProcess] mingle: searching for neighbors
# [2025-07-09 13:08:19,196: INFO/MainProcess] mingle: all alone
# [2025-07-09 13:08:19,220: INFO/MainProcess] celery@91de2d820aa3 ready.
# [2025-07-09 13:11:37,747: ERROR/MainProcess] Received unregistered task of type 'experiments_IBM_run.run_experiment_task_IBM'.
# The message has been ignored and discarded.
#
# Did you remember to import the module containing this task?
# Or maybe you're using relative imports?
#
# Please see
# https://docs.celeryq.dev/en/latest/internals/protocol.html
# for more information.
#
# The full contents of the message body was:
# b'[[{"model_type": "QNN", "learning_rate": 0.001, "batch_size": 50, "num_features": 4, "init_std": 1, "init_std_Q": 1, "layer_depth": 1, "num_frequencies": 5, "weight_decay": 0, "t_wait": 1e-08, "ind_trajectory": 0}, 2000, "mysql+mysqlconnector://slava:3dnvbeu82$@172.17.0.2/mlflow_db", null, false, true, 0, 0, 0.095, "IBM_regulariation"], {}, {"callbacks": null, "errbacks": null, "chain": null, "chord": null}]' (411b)
#
# The full contents of the message headers:
# {'lang': 'py', 'task': 'experiments_IBM_run.run_experiment_task_IBM', 'id': '9a9cd401-29b1-45b4-beaa-7dc484fc816b', 'shadow': None, 'eta': None, 'expires': None, 'group': None, 'group_index': None, 'retries': 0, 'timelimit': [None, None], 'root_id': '9a9cd401-29b1-45b4-beaa-7dc484fc816b', 'parent_id': None, 'argsrepr': "({'model_type': 'QNN', 'learning_rate': 0.001, 'batch_size': 50, 'num_features': 4, 'init_std': 1, 'init_std_Q': 1, 'layer_depth': 1, 'num_frequencies': 5, 'weight_decay': 0, 't_wait': 1e-08, 'ind_trajectory': 0}, 2000, 'mysql+mysqlconnector://slava:3dnvbeu82$@172.17.0.2/mlflow_db', None, False, True, 0, 0, 0.095, 'IBM_regulariation')", 'kwargsrepr': '{}', 'origin': 'gen249119@91de2d820aa3', 'ignore_result': False, 'replaced_task_nesting': 0, 'stamped_headers': None, 'stamps': {}}
#
# The delivery info for this task is:
# {'exchange': '', 'routing_key': 'celery'}
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/celery/worker/consumer/consumer.py", line 662, in on_task_received
#     strategy = strategies[type_]
# KeyError: 'experiments_IBM_run.run_experiment_task_IBM'
# [2025-07-09 13:11:37,751: ERROR/MainProcess] Received unregistered task of type 'experiments_IBM_run.run_experiment_task_IBM'.
# The message has been ignored and discarded.
#
# Did you remember to import the module containing this task?
# Or maybe you're using relative imports?
#
# Please see
# https://docs.celeryq.dev/en/latest/internals/protocol.html
# for more information.
#
# The full contents of the message body was:
# b'[[{"model_type": "QNN", "learning_rate": 0.001, "batch_size": 50, "num_features": 4, "init_std": 1, "init_std_Q": 1, "layer_depth": 1, "num_frequencies": 5, "weight_decay": 0, "t_wait": 1e-08, "ind_trajectory": 1}, 2000, "mysql+mysqlconnector://slava:3dnvbeu82$@172.17.0.2/mlflow_db", null, false, true, 0, 0, 0.095, "IBM_regulariation"], {}, {"callbacks": null, "errbacks": null, "chain": null, "chord": null}]' (411b)
#
# The full contents of the message headers:
# {'lang': 'py', 'task': 'experiments_IBM_run.run_experiment_task_IBM', 'id': '4f8b31ae-dfde-45f1-a1d2-0f137a96961a', 'shadow': None, 'eta': None, 'expires': None, 'group': None, 'group_index': None, 'retries': 0, 'timelimit': [None, None], 'root_id': '4f8b31ae-dfde-45f1-a1d2-0f137a96961a', 'parent_id': None, 'argsrepr': "({'model_type': 'QNN', 'learning_rate': 0.001, 'batch_size': 50, 'num_features': 4, 'init_std': 1, 'init_std_Q': 1, 'layer_depth': 1, 'num_frequencies': 5, 'weight_decay': 0, 't_wait': 1e-08, 'ind_trajectory': 1}, 2000, 'mysql+mysqlconnector://slava:3dnvbeu82$@172.17.0.2/mlflow_db', None, False, True, 0, 0, 0.095, 'IBM_regulariation')", 'kwargsrepr': '{}', 'origin': 'gen249119@91de2d820aa3', 'ignore_result': False, 'replaced_task_nesting': 0, 'stamped_headers': None, 'stamps': {}}
#
# The delivery info for this task is:
# {'exchange': '', 'routing_key': 'celery'}
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/celery/worker/consumer/consumer.py", line 662, in on_task_received
#     strategy = strategies[type_]
# KeyError: 'experiments_IBM_run.run_experiment_task_IBM'
# [2025-07-09 13:11:37,753: ERROR/MainProcess] Received unregistered task of type 'experiments_IBM_run.run_experiment_task_IBM'.
# The message has been ignored and discarded.
#
# Did you remember to import the module containing this task?
# Or maybe you're using relative imports?
#
# Please see
# https://docs.celeryq.dev/en/latest/internals/protocol.html
# for more information.
#
# The full contents of the message body was:
# b'[[{"model_type": "QNN", "learning_rate": 0.001, "batch_size": 50, "num_features": 4, "init_std": 1, "init_std_Q": 1, "layer_depth": 1, "num_frequencies": 5, "weight_decay": 0, "t_wait": 1e-08, "ind_trajectory": 2}, 2000, "mysql+mysqlconnector://slava:3dnvbeu82$@172.17.0.2/mlflow_db", null, false, true, 0, 0, 0.095, "IBM_regulariation"], {}, {"callbacks": null, "errbacks": null, "chain": null, "chord": null}]' (411b)
#
# The full contents of the message headers:
# {'lang': 'py', 'task': 'experiments_IBM_run.run_experiment_task_IBM', 'id': '57a21ffd-061a-4b5f-8e4e-e0bca45ce1ca', 'shadow': None, 'eta': None, 'expires': None, 'group': None, 'group_index': None, 'retries': 0, 'timelimit': [None, None], 'root_id': '57a21ffd-061a-4b5f-8e4e-e0bca45ce1ca', 'parent_id': None, 'argsrepr': "({'model_type': 'QNN', 'learning_rate': 0.001, 'batch_size': 50, 'num_features': 4, 'init_std': 1, 'init_std_Q': 1, 'layer_depth': 1, 'num_frequencies': 5, 'weight_decay': 0, 't_wait': 1e-08, 'ind_trajectory': 2}, 2000, 'mysql+mysqlconnector://slava:3dnvbeu82$@172.17.0.2/mlflow_db', None, False, True, 0, 0, 0.095, 'IBM_regulariation')", 'kwargsrepr': '{}', 'origin': 'gen249119@91de2d820aa3', 'ignore_result': False, 'replaced_task_nesting': 0, 'stamped_headers': None, 'stamps': {}}
#
# The delivery info for this task is:
# {'exchange': '', 'routing_key': 'celery'}
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/celery/worker/consumer/consumer.py", line 662, in on_task_received
#     strategy = strategies[type_]
# KeyError: 'experiments_IBM_run.run_experiment_task_IBM'
# [2025-07-09 13:11:37,754: ERROR/MainProcess] Received unregistered task of type 'experiments_IBM_run.run_experiment_task_IBM'.
# The message has been ignored and discarded.
#
# Did you remember to import the module containing this task?
# Or maybe you're using relative imports?
#
# Please see
# https://docs.celeryq.dev/en/latest/internals/protocol.html
# for more information.
#
# The full contents of the message body was:
# b'[[{"model_type": "QNN", "learning_rate": 0.001, "batch_size": 50, "num_features": 4, "init_std": 1, "init_std_Q": 1, "layer_depth": 1, "num_frequencies": 5, "weight_decay": 0, "t_wait": 1e-08, "ind_trajectory": 3}, 2000, "mysql+mysqlconnector://slava:3dnvbeu82$@172.17.0.2/mlflow_db", null, false, true, 0, 0, 0.095, "IBM_regulariation"], {}, {"callbacks": null, "errbacks": null, "chain": null, "chord": null}]' (411b)
#
# The full contents of the message headers:
# {'lang': 'py', 'task': 'experiments_IBM_run.run_experiment_task_IBM', 'id': 'd669ed60-81b1-4eca-895c-c5f00476438a', 'shadow': None, 'eta': None, 'expires': None, 'group': None, 'group_index': None, 'retries': 0, 'timelimit': [None, None], 'root_id': 'd669ed60-81b1-4eca-895c-c5f00476438a', 'parent_id': None, 'argsrepr': "({'model_type': 'QNN', 'learning_rate': 0.001, 'batch_size': 50, 'num_features': 4, 'init_std': 1, 'init_std_Q': 1, 'layer_depth': 1, 'num_frequencies': 5, 'weight_decay': 0, 't_wait':
, 2000, 'mysql+mysqlconnector://slava:3dnvbeu82$@172.17.0.2/mlflow_db', None, False, True, 0, 0, 0.095, 'IBM_regulariation')", 'kwargsrepr': '{}', 'origin': 'gen334207@91de2d820aa3', 'ignore_result': False, 'replaced_task_nesting': 0, 'stamped_headers': None, 'stamps': {}}
#
# The delivery info for this task is:
# {'exchange': '', 'routing_key': 'celery'}
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/celery/worker/consumer/consumer.py", line 662, in on_task_received
#     strategy = strategies[type_]
# KeyError: 'experiments_IBM_run.run_experiment_task_IBM'
# [2025-07-09 13:15:04,550: ERROR/MainProcess] Received unregistered task of type 'experiments_IBM_run.run_experiment_task_IBM'.
# The message has been ignored and discarded.
#
# Did you remember to import the module containing this task?
# Or maybe you're using relative imports?
#
# Please see
# https://docs.celeryq.dev/en/latest/internals/protocol.html
# for more information.
#
# The full contents of the message body was:
# b'[[{"model_type": "QNN", "learning_rate": 0.001, "batch_size": 50, "num_features": 4, "init_std": 1, "init_std_Q": 1, "layer_depth": 1, "num_frequencies": 5, "weight_decay": 0, "t_wait": 9.999999999999999e-05, "ind_trajectory": 2}, 2000, "mysql+mysqlconnector://slava:3dnvbeu82$@172.17.0.2/mlflow_db", null, false, true, 0, 0, 0.095, "IBM_regulariation"], {}, {"callbacks": null, "errbacks": null, "chain": null, "chord": null}]' (427b)
#
# The full contents of the message headers:
# {'lang': 'py', 'task': 'experiments_IBM_run.run_experiment_task_IBM', 'id': '3fe3e44a-501b-4fde-8a4b-790f8043e489', 'shadow': None, 'eta': None, 'expires': None, 'group': None, 'group_index': None, 'retries': 0, 'timelimit': [None, None], 'root_id': '3fe3e44a-501b-4fde-8a4b-790f8043e489', 'parent_id': None, 'argsrepr': "({'model_type': 'QNN', 'learning_rate': 0.001, 'batch_size': 50, 'num_features': 4, 'init_std': 1, 'init_std_Q': 1, 'layer_depth': 1, 'num_frequencies': 5, 'weight_decay': 0, 't_wait': 9.999999999999999e-05, 'ind_trajectory': 2}, 2000, 'mysql+mysqlconnector://slava:3dnvbeu82$@172.17.0.2/mlflow_db', None, False, True, 0, 0, 0.095, 'IBM_regulariation')", 'kwargsrepr': '{}', 'origin': 'gen334207@91de2d820aa3', 'ignore_result': False, 'replaced_task_nesting': 0, 'stamped_headers': None, 'stamps': {}}
#
# The delivery info for this task is:
# {'exchange': '', 'routing_key': 'celery'}
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/celery/worker/consumer/consumer.py", line 662, in on_task_received
#     strategy = strategies[type_]
# KeyError: 'experiments_IBM_run.run_experiment_task_IBM'
# [2025-07-09 13:15:04,552: ERROR/MainProcess] Received unregistered task of type 'experiments_IBM_run.run_experiment_task_IBM'.
# The message has been ignored and discarded.
#
# Did you remember to import the module containing this task?
# Or maybe you're using relative imports?
#
# Please see
# https://docs.celeryq.dev/en/latest/internals/protocol.html
# for more information.
#
# The full contents of the message body was:
# b'[[{"model_type": "QNN", "learning_rate": 0.001, "batch_size": 50, "num_features": 4, "init_std": 1, "init_std_Q": 1, "layer_depth": 1, "num_frequencies": 5, "weight_decay": 0, "t_wait": 9.999999999999999e-05, "ind_trajectory": 3}, 2000, "mysql+mysqlconnector://slava:3dnvbeu82$@172.17.0.2/mlflow_db", null, false, true, 0, 0, 0.095, "IBM_regulariation"], {}, {"callbacks": null, "errbacks": null, "chain": null, "chord": null}]' (427b)
#
# The full contents of the message headers:
# {'lang': 'py', 'task': 'experiments_IBM_run.run_experiment_task_IBM', 'id': 'e21ac35c-9287-4dca-a9db-f7ed5ebdadb8', 'shadow': None, 'eta': None, 'expires': None, 'group': None, 'group_index': None, 'retries': 0, 'timelimit': [None, None], 'root_id': 'e21ac35c-9287-4dca-a9db-f7ed5ebdadb8', 'parent_id': None, 'argsrepr': "({'model_type': 'QNN', 'learning_rate': 0.001, 'batch_size': 50, 'num_features': 4, 'init_std': 1, 'init_std_Q': 1, 'layer_depth': 1, 'num_frequencies': 5, 'weight_decay': 0, 't_wait': 9.999999999999999e-05, 'ind_trajectory': 3}, 2000, 'mysql+mysqlconnector://slava:3dnvbeu82$@172.17.0.2/mlflow_db', None, False, True, 0, 0, 0.095, 'IBM_regulariation')", 'kwargsrepr': '{}', 'origin': 'gen334207@91de2d820aa3', 'ignore_result': False, 'replaced_task_nesting': 0, 'stamped_headers': None, 'stamps': {}}
#
# The delivery info for this task is:
# {'exchange': '', 'routing_key': 'celery'}
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/celery/worker/consumer/consumer.py", line 662, in on_task_received
#     strategy = strategies[type_]
# KeyError: 'experiments_IBM_run.run_experiment_task_IBM'
# [2025-07-09 13:15:04,553: ERROR/MainProcess] Received unregistered task of type 'experiments_IBM_run.run_experiment_task_IBM'.
# The message has been ignored and discarded.
#
# Did you remember to import the module containing this task?
# Or maybe you're using relative imports?
#
# Please see
# https://docs.celeryq.dev/en/latest/internals/protocol.html
# for more information.
#
# The full contents of the message body was:
# b'[[{"model_type": "QNN", "learning_rate": 0.001, "batch_size": 50, "num_features": 4, "init_std": 1, "init_std_Q": 1, "layer_depth": 1, "num_frequencies": 5, "weight_decay": 0, "t_wait": 9.999999999999999e-05, "ind_trajectory": 4}, 2000, "mysql+mysqlconnector://slava:3dnvbeu82$@172.17.0.2/mlflow_db", null, false, true, 0, 0, 0.095, "IBM_regulariation"], {}, {"callbacks": null, "errbacks": null, "chain": null, "chord": null}]' (427b)
#
# The full contents of the message headers:
# {'lang': 'py', 'task': 'experiments_IBM_run.run_experiment_task_IBM', 'id': '3bb60b61-6680-4641-96c5-fb7e9f7533a3', 'shadow': None, 'eta': None, 'expires': None, 'group': None, 'group_index': None, 'retries': 0, 'timelimit': [None, None], 'root_id': '3bb60b61-6680-4641-96c5-fb7e9f7533a3', 'parent_id': None, 'argsrepr': "({'model_type': 'QNN', 'learning_rate': 0.001, 'batch_size': 50, 'num_features': 4, 'init_std': 1, 'init_std_Q': 1, 'layer_depth': 1, 'num_frequencies': 5, 'weight_decay': 0, 't_wait': 9.999999999999999e-05, 'ind_trajectory': 4}, 2000, 'mysql+mysqlconnector://slava:3dnvbeu82$@172.17.0.2/mlflow_db', None, False, True, 0, 0, 0.095, 'IBM_regulariation')", 'kwargsrepr': '{}', 'origin': 'gen334207@91de2d820aa3', 'ignore_result': False, 'replaced_task_nesting': 0, 'stamped_headers': None, 'stamps': {}}
#
# The delivery info for this task is:
# {'exchange': '', 'routing_key': 'celery'}
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/celery/worker/consumer/consumer.py", line 662, in on_task_received
#     strategy = strategies[type_]
# KeyError: 'experiments_IBM_run.run_experiment_task_IBM'
# ^C
#
# worker: Hitting Ctrl+C again will initiate cold shutdown, terminating all running tasks!
#
# worker: Warm shutdown (MainProcess)

# %%
# !celery -A experiments_IBM_run -b redis://172.17.0.2:6379/0 --result-backend redis://172.17.0.2:6379/0 worker --loglevel=info --concurrency=48

# %%
1

# %%
1
